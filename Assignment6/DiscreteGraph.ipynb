# %% [markdown]
# Discrete Graphs for Trigonometric Functions

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %matplotlib inline

k = np.arange(0,8,0.1)
x = np.cos(2*k*np.pi/4)

plt.stem(k, x, use_line_collection=True)
# Out:
# <StemContainer object of 3 artists>

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %matplotlib inline

k = np.arange(0,8,0.1)
x = np.cos(2*k*np.pi/8)

plt.stem(k, x, use_line_collection=True)
# Out:
# <StemContainer object of 3 artists>

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %matplotlib inline

k = np.arange(0,8,0.1)
x = np.sin(2*k*np.pi/4)

plt.stem(k, x, use_line_collection=True)
# Out:
# <StemContainer object of 3 artists>

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %matplotlib inline

k = np.arange(0,8,0.1)
x = np.sin(2*k*np.pi/8)

plt.stem(k, x, use_line_collection=True)
# Out:
# <StemContainer object of 3 artists>

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %matplotlib inline

k = np.arange(0,8,0.1)
x = np.tan(2*k*np.pi/4)

plt.stem(k, x, use_line_collection=True)
# Out:
# <StemContainer object of 3 artists>

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %matplotlib inline

k = np.arange(0,8,0.1)
x = np.tan(2*k*np.pi/8)

plt.stem(k, x, use_line_collection=True)
# Out:
# <StemContainer object of 3 artists>
