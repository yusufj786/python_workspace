# %% [markdown]
# Extract the features of 2 RGB images

# %%
# https://analyticsindiamag.com/image-feature-extraction-using-scikit-image-a-hands-on-guide/

# %%
#Importing the required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.io import imread, imshow

# %%
# Loading the image

image1 = imread('elephant.jpg')
imshow(image1);

# %%
# Loading the image

image2 = imread('elephant.jpg', as_gray=True)
imshow(image2)

# %%
# Analyzing both the images

print(image1.shape)
print(image2.shape)
# Out:
# (251, 477, 3)
# (251, 477)

# %%
print(image1.size)
print(image2.size)
# Out:
# 359181
# 119727

# %%
# Feature Extraction

# Pixel Features

pixel_feat1 = np.reshape(image2, (1080 * 1920))
pixel_feat1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\SAGAR\OneDrive\Desktop\AI with Python\AIwithPython\Assignment\Assignment7\ExtractingFeaturesRGB.ipynb Cell 8 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/SAGAR/OneDrive/Desktop/AI%20with%20Python/AIwithPython/Assignment/Assignment7/ExtractingFeaturesRGB.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> # Feature Extraction
#       <a href='vscode-notebook-cell:/c%3A/Users/SAGAR/OneDrive/Desktop/AI%20with%20Python/AIwithPython/Assignment/Assignment7/ExtractingFeaturesRGB.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a>
#       <a href='vscode-notebook-cell:/c%3A/Users/SAGAR/OneDrive/Desktop/AI%20with%20Python/AIwithPython/Assignment/Assignment7/ExtractingFeaturesRGB.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> # Pixel Features
# ----> <a href='vscode-notebook-cell:/c%3A/Users/SAGAR/OneDrive/Desktop/AI%20with%20Python/AIwithPython/Assignment/Assignment7/ExtractingFeaturesRGB.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a> pixel_feat1 = np.reshape(image2, (1080 * 1920))
#       <a href='vscode-notebook-cell:/c%3A/Users/SAGAR/OneDrive/Desktop/AI%20with%20Python/AIwithPython/Assignment/Assignment7/ExtractingFeaturesRGB.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a> pixel_feat1
#
# File <__array_function__ internals>:5, in reshape(*args, **kwargs)
#
# File c:\Program Files\Python\lib\site-packages\numpy\core\fromnumeric.py:298, in reshape(a, newshape, order)
#     198 @array_function_dispatch(_reshape_dispatcher)
#     199 def reshape(a, newshape, order='C'):
#     200     """
#     201     Gives a new shape to an array without changing its data.
#     202
#    (...)
#     296            [5, 6]])
#     297     """
# --> 298     return _wrapfunc(a, 'reshape', newshape, order=order)
#
# File c:\Program Files\Python\lib\site-packages\numpy\core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# ValueError: cannot reshape array of size 119727 into shape (2073600,)

# %%
pixel_feat2 = np.reshape(image1, (1080 * 1920 * 3))
pixel_feat2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\SAGAR\OneDrive\Desktop\AI with Python\AIwithPython\Assignment\Assignment7\ExtractingFeaturesRGB.ipynb Cell 9 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/SAGAR/OneDrive/Desktop/AI%20with%20Python/AIwithPython/Assignment/Assignment7/ExtractingFeaturesRGB.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> pixel_feat2 = np.reshape(image1, (1080 * 1920 * 3))
#       <a href='vscode-notebook-cell:/c%3A/Users/SAGAR/OneDrive/Desktop/AI%20with%20Python/AIwithPython/Assignment/Assignment7/ExtractingFeaturesRGB.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> pixel_feat2
#
# File <__array_function__ internals>:5, in reshape(*args, **kwargs)
#
# File c:\Program Files\Python\lib\site-packages\numpy\core\fromnumeric.py:298, in reshape(a, newshape, order)
#     198 @array_function_dispatch(_reshape_dispatcher)
#     199 def reshape(a, newshape, order='C'):
#     200     """
#     201     Gives a new shape to an array without changing its data.
#     202
#    (...)
#     296            [5, 6]])
#     297     """
# --> 298     return _wrapfunc(a, 'reshape', newshape, order=order)
#
# File c:\Program Files\Python\lib\site-packages\numpy\core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# ValueError: cannot reshape array of size 359181 into shape (6220800,)

# %%
""" 
1.Prewitt Kernel
2.Sobel Kernel
3.Canny Algorithm

Using these three algorithms for edge feature extraction.

"""

# %%
from skimage import filters

# prewitt kernel
pre_hor = prewitt_h(image2)
pre_ver = prewitt_v(image2)

# Sobel Kernel
ed_sobel = filters.sobel(image2)

#canny algorithm
can = feature.canny(image2)

imshow(pre_ver, cmap='gray');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\SAGAR\OneDrive\Desktop\AI with Python\AIwithPython\Assignment\Assignment7\ExtractingFeaturesRGB.ipynb Cell 11 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/SAGAR/OneDrive/Desktop/AI%20with%20Python/AIwithPython/Assignment/Assignment7/ExtractingFeaturesRGB.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> from skimage import filters
#       <a href='vscode-notebook-cell:/c%3A/Users/SAGAR/OneDrive/Desktop/AI%20with%20Python/AIwithPython/Assignment/Assignment7/ExtractingFeaturesRGB.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> # prewitt kernel
# ----> <a href='vscode-notebook-cell:/c%3A/Users/SAGAR/OneDrive/Desktop/AI%20with%20Python/AIwithPython/Assignment/Assignment7/ExtractingFeaturesRGB.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a> pre_hor = prewitt_h(image2)
#       <a href='vscode-notebook-cell:/c%3A/Users/SAGAR/OneDrive/Desktop/AI%20with%20Python/AIwithPython/Assignment/Assignment7/ExtractingFeaturesRGB.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a> pre_ver = prewitt_v(image2)
#       <a href='vscode-notebook-cell:/c%3A/Users/SAGAR/OneDrive/Desktop/AI%20with%20Python/AIwithPython/Assignment/Assignment7/ExtractingFeaturesRGB.ipynb#X15sZmlsZQ%3D%3D?line=6'>7</a> # Sobel Kernel
#
# NameError: name 'prewitt_h' is not defined

# %%
imshow(pre_hor, cmap='gray');

# %%
imshow(ed_sobel, cmap='gray');

# %%
imshow(can, cmap='gray');

# %% [markdown]
# Region-Based Segmentation

# %%
from skimage.exposure import histogram
hist, hist_centers = histogram(image2)

#Plotting the Image and the Histogram of gray values
fig, axes = plt.subplots(1, 2, figsize=(8, 3))
axes[0].imshow(image2, cmap=plt.cm.gray)
axes[0].axis('off')
axes[1].plot(hist_centers, hist, lw=2)
axes[1].set_title('histogram of gray values')
